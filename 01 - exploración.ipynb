# %% [markdown]
# Trabajaremos en una competencia del sitio web Kaggle donde su información está disponible en el siguiente vínculo web:
# https://www.kaggle.com/competitions/udea-ai-4-eng-20251-pruebas-saber-pro-colombia
#
# Para acceder y utilizar los datos en los notebooks de Colab, se requiere seguir estos pasos: Generar un Token de API: Es necesario crear un token desde tu cuenta de Kaggle para descargar archivos desde el cuaderno de Jupyter. Para hacerlo, dirígete a la configuración de tu perfil en Kaggle, haz clic en "Crear Nuevo Token de API", y descarga el archivo kaggle.json, y posteriormente lo guardas en la mims acarpeta donde ejecutas el colab. Este archivo contiene tu nombre de usuario y el token necesario para la descarga de archivos.
#
# Una vez se hayan realizado estos dos pasos, con este bloque de código se pueden descargar los archivos.
#
# Después, es necesario ingresar al directorio que alberga los archivos descargados para comenzar a trabajar con ellos.

# %% [markdown]
# Esta linea otroga permisos de escritura y de lectura sobre el archivo kaggle.json

# %%
# !chmod 600 kaggle.json

# %% [markdown]
# La siguientes lineas de códigos importan la slibrerías necesarías.

# %%
import pandas as pd
import os

# %% [markdown]
# La sigueinte linea hace que guarde el colab en la carpeta actual de trabajo, que es donde se subió manualmente el archivo kaggle.json con los datos del token para descargar los archivos test y train de la competencia de kaggle.

# %%
os.environ['KAGGLE_CONFIG_DIR'] = '.'

# %% [markdown]
# Con la siguiente linea se descargan los archivos de kaggle y se suben directamente a nuetsro entrono de google colab.

# %%
# !kaggle competitions download -c udea-ai-4-eng-20251-pruebas-saber-pro-colombia
# Out:
# udea-ai-4-eng-20251-pruebas-saber-pro-colombia.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# Procedemos a descomprimir los archivos directamente desde kaggle.

# %%
# !unzip udea-ai-4-eng-20251-pruebas-saber-pro-colombia.zip
# Out:
# Archive:  udea-ai-4-eng-20251-pruebas-saber-pro-colombia.zip
#   inflating: submission_example.csv
#   inflating: test.csv
#   inflating: train.csv

# %% [markdown]
# Se asigan los archivos train y test a variables independinetes.

# %%
z_train = pd.read_csv('train.csv')
z_test = pd.read_csv('test.csv')

# %% [markdown]
# Luego podemos visualizar los archivos que ya tenemos descargados y en comuniciación entre kaggle y Colab.

# %% [markdown]
# Con el comando head() podemos ver la cabecera de las columnas con los nombres y los datos que contienen

# %%
z_train.head()
# Out:
#        ID  PERIODO         ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0  904256    20212                  ENFERMERIA                 BOGOTÁ
# 1  645256    20212                     DERECHO              ATLANTICO
# 2  308367    20203       MERCADEO Y PUBLICIDAD                 BOGOTÁ
# 3  470353    20195  ADMINISTRACION DE EMPRESAS              SANTANDER
# 4  989032    20212                  PSICOLOGIA              ANTIOQUIA
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                       0
# 2  Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                       0
# 4  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET                 FAMI_EDUCACIONPADRE  \
# ...

# %%
z_test.head()
# Out:
#        ID  PERIODO                     ESTU_PRGM_ACADEMICO  \
# 0  550236    20183                          TRABAJO SOCIAL
# 1   98545    20203  ADMINISTRACION COMERCIAL Y DE MERCADEO
# 2  499179    20212                  INGENIERIA MECATRONICA
# 3  782980    20195                      CONTADURIA PUBLICA
# 4  785185    20212              ADMINISTRACION DE EMPRESAS
#
#   ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 0                BOLIVAR                          Menos de 500 mil
# 1              ANTIOQUIA  Entre 2.5 millones y menos de 4 millones
# 2                 BOGOTÁ    Entre 1 millón y menos de 2.5 millones
# 3                  SUCRE    Entre 1 millón y menos de 2.5 millones
# 4              ATLANTICO  Entre 2.5 millones y menos de 4 millones
#
#   ESTU_HORASSEMANATRABAJA FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# 0       Menos de 10 horas            Estrato 3                 Si
# 1     Entre 21 y 30 horas            Estrato 2                 Si
# ...

# %% [markdown]
# Con este comando llamado 'value_counts' podemos acceder a las columnas que quiero visualizar para obtener la información necesaria para el modelo a utilizar.

# %%
z_test.ESTU_PRGM_ACADEMICO.value_counts()
# Out:
# ESTU_PRGM_ACADEMICO
# DERECHO                                                                                                 22984
# ADMINISTRACION DE EMPRESAS                                                                              22298
# CONTADURIA PUBLICA                                                                                      16861
# PSICOLOGIA                                                                                              13818
# INGENIERIA INDUSTRIAL                                                                                   12516
#                                                                                                         ...
# INGENIERIA EN DISEÑO INDUSTRIAL                                                                             1
# LICENC.EN EDUCACION BASICA PRIMARIA ENF.EN CIENCIAS NATURALESEDUC.AMBIENTAL MATEMA.LENGUA CASTELLANA        1
# ...

# %%
z_train.ESTU_VALORMATRICULAUNIVERSIDAD.value_counts()
# Out:
# ESTU_VALORMATRICULAUNIVERSIDAD
# Entre 1 millón y menos de 2.5 millones      204048
# Entre 2.5 millones y menos de 4 millones    127430
# Menos de 500 mil                             80263
# Entre 500 mil y menos de 1 millón            78704
# Entre 4 millones y menos de 5.5 millones     69736
# Más de 7 millones                            68014
# Entre 5.5 millones y menos de 7 millones     38490
# No pagó matrícula                            19528
# Name: count, dtype: int64
